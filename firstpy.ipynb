# %% [markdown]
# <a href="https://colab.research.google.com/github/pchandrabose/colab-examples/blob/master/firstpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %config InlineBackend.figure_format = 'svg'

learning_rate = 0.01
ephocs = 200
n_samples = 30
train_x = np.linspace(0,20,n_samples)
train_y = 3 * train_x + 4 * np.random.randn(n_samples)

plt.plot(train_x,train_y,'o')
plt.plot(train_x, 3* train_x)

plt.show()

# %%
X = tf.P(tf.float32)
Y = tf.placeholder(tf.float32)
W = tf.Variable(np.random.randn(),'weights')
B = tf.Variable(np.random.randn(),'bias')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f0ba558b7eb2> in <module>()
# ----> 1 X = tf.placeholder(tf.float32)
#       2 Y = tf.placeholder(tf.float32)
#       3 W = tf.Variable(np.random.randn(),'weights')
#       4 B = tf.Variable(np.random.randn(),'bias')
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
pred = X * W + B
cost = tf.reduce_sum( (pred - y) ** 2) / (2 * n_samples)
optimizer = tf.train.GradientDecentOptimizer(learning_rate).minimize(cost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bfe899d762c0> in <module>()
# ----> 1 pred = X * W + B
#       2 cost = tf.reduce_sum( (pred - y) ** 2) / (2 * n_samples)
#       3 optimizer = tf.train.GradientDecentOptimizer(learning_rate).minimize(cost)
#
# NameError: name 'X' is not defined
